# %%
## import require libraries #########
import numpy as np
import pandas as pd
from matplotlib import cm
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.gridspec as gridspec
import matplotlib
import matplotlib.dates as mdates
import datetime as dt
import mplcyberpunk
from matplotlib import rcParams
#plt.style.use("cyberpunk")
#mplcyberpunk.add_glow_effects()
#mplcyberpunk.make_lines_glow()
#mplcyberpunk.add_underglow()
"""Control font"""
matplotlib.rcParams['font.family'] = "sans-serif"
matplotlib.rcParams['font.sans-serif'] = "Times New Roman"


#=============================================================================
### Read met files
df  = pd.read_excel(r'/mnt/g/Paper_work/Beijing.xlsx',sheet_name='Sheet1')
df1 = pd.read_excel(r'/mnt/g/Paper_work/Chengdu.xlsx',sheet_name='Sheet1')
df2 = pd.read_excel(r'/mnt/g/Paper_work/Langtang.xlsx',sheet_name='Sheet1')
df3 = pd.read_excel(r'/mnt/g/Paper_work/New_Delhi.xlsx',sheet_name='Sheet1')
df4 = pd.read_excel(r'/mnt/g/Paper_work/Pakistan_karachi.xlsx',sheet_name='Sheet1')
df5 = pd.read_excel(r'/mnt/g/Paper_work/Uzbekistan.xlsx',sheet_name='Sheet1')
#======================================================================================
fig, ax  =  plt.subplots(nrows=6,ncols=3, figsize=(6,4),dpi=300)
fig.autofmt_xdate()

#==== Add effect neo effects using cyberpunk ======
#plt.style.use("cyberpunk")
#mplcyberpunk.add_glow_effects()
#mplcyberpunk.make_lines_glow()
#mplcyberpunk.add_underglow()
#mplcyberpunk.make_lines_glow(ax)
#=========  plotting for Beijing ==================
ax[0,0].plot(df.Date, df.Temp_Obs, color='tab:cyan' ,label='Obs_Tempr',linewidth=0.5)
ax[0,0].plot(df.Date, df.Temp_Mod,color='tab:olive', linestyle='--',label='Mod_Tempr',linewidth=0.5)
ax[0,0].set_title("Temperature $[^oC]$",fontsize=5)
ax[0,0].set_ylabel('Beijing',fontsize=5)
ax[0,0].set_yticks([-10,0,10,20,30])
#mplcyberpunk.make_lines_glow(ax[0,1])
#=== RH 
ax[0,1].plot(df.Date, df.RH_Obs, color='tab:cyan' ,label='Obs_RH',linewidth=0.5)
ax[0,1].plot(df.Date, df.RH_Mod,color='tab:olive', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[0,1].set_title('Relative Humidity [%]',fontsize=5)
ax[0,1].set_yticks([0,25,50,75,100])

#===== plot Wind speed==========================
ax[0,2].plot(df.Date, df.WS_Obs, color='tab:cyan' ,label='Obs_Ws',linewidth=0.5)
ax[0,2].plot(df.Date, df.WS_Mod,color='tab:olive', linestyle='--',label='Mod_Ws',linewidth=0.5)
ax[0,2].set_title('Wind Speed [m/s]',fontsize=5)
ax[0,2].set_yticks([0,5,10,15,20])

ax[0,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)

ax[0,0].tick_params(axis='y', labelsize= 5)
ax[0,1].tick_params(axis='y', labelsize= 5)
ax[0,2].tick_params(axis='y', labelsize= 5)

ax[0,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[0,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[0,2].set(xlim=["2017-01-01", "2017-12-31"])

ax[0,0].set_xticklabels([])
ax[0,1].set_xticklabels([])
ax[0,2].set_xticklabels([])

#==== High light seasonal basis =====

#===== Temperature Winter========
ax[0,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[1,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[2,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[3,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[4,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[5,0].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
#== Add December month
ax[0,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[1,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[2,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[3,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[4,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[5,0].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
#==== Temperature Spring =========
ax[0,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[1,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[2,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[3,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[4,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[5,0].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
#==== Temperature Summer =========
ax[0,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[1,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[2,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[3,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[4,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[5,0].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)

#==== Temperature Summer =========
ax[0,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[1,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[2,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[3,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[4,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[5,0].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)

#====For RH =======
#=====  Winter========
ax[0,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[1,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[2,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[3,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[4,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[5,1].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
#== Add December month
ax[0,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[1,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[2,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[3,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[4,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[5,1].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
#==== Temperature Spring =========
ax[0,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[1,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[2,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[3,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[4,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[5,1].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
#==== Temperature Summer =========
ax[0,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[1,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[2,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[3,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[4,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[5,1].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)

#==== Temperature Autumn =========
ax[0,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[1,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[2,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[3,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[4,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[5,1].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)

#==For Wind Speed ========
#=====  Winter========
ax[0,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[1,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[2,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[3,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[4,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
ax[5,2].axvspan(*mdates.datestr2num(['01/01/2017', '02/28/2017']), color='silver', alpha=0.5)
#== Add December month
ax[0,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[1,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[2,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[3,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[4,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
ax[5,2].axvspan(*mdates.datestr2num(['12/01/2017', '12/30/2017']), color='silver', alpha=0.5)
#==== Temperature Spring =========
ax[0,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[1,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[2,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[3,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[4,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
ax[5,2].axvspan(*mdates.datestr2num(['03/01/2017', '05/31/2017']), color='salmon', alpha=0.2)
#==== Temperature Summer =========
ax[0,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[1,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[2,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[3,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[4,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)
ax[5,2].axvspan(*mdates.datestr2num(['06/01/2017', '08/31/2017']), color='darkturquoise', alpha=0.2)

#==== Temperature Autumn =========
ax[0,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[1,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[2,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[3,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[4,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)
ax[5,2].axvspan(*mdates.datestr2num(['09/01/2017', '11/30/2017']), color='fuchsia', alpha=0.1)

##========= Plot  for Chengdu ========================
##========= Temp =======
ax[1,0].plot(df1.Date, df1.Temp_Obs, color='tab:orange' ,label='Obs_Tempr',linewidth=0.5)
ax[1,0].plot(df1.Date, df1.Temp_Mod,color='tab:green', linestyle='--',label='Mod_Tempr',linewidth=0.5)

ax[1,0].set_ylabel('Chengdu',fontsize=5)
ax[1,0].set_yticks([-10,0,10,20,30])

ax[1,1].plot(df1.Date, df1.RH_Obs, color='tab:orange' ,label='Obs_RH',linewidth=0.5)
ax[1,1].plot(df1.Date, df1.RH_Mod,color='tab:green', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[1,1].set_yticks([0,25,50,75,100])


ax[1,2].plot(df1.Date, df1.WS_Obs, color='tab:orange' ,label='Obs_Ws',linewidth=0.5)
ax[1,2].plot(df1.Date, df1.WS_Mod,color='tab:green', linestyle='--',label='Mod_Ws',linewidth=0.5)

ax[1,2].set_yticks([0,5,10,15,20])
ax[1,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)

ax[1,0].tick_params(axis='y', labelsize= 5)
ax[1,1].tick_params(axis='y', labelsize= 5)
ax[1,2].tick_params(axis='y', labelsize= 5)

ax[1,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[1,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[1,2].set(xlim=["2017-01-01", "2017-12-31"])

ax[1,0].set_xticklabels([])
ax[1,1].set_xticklabels([])
ax[1,2].set_xticklabels([])

#===========  Plot for  Langtang =========================================
ax[2,0].plot(df2.Date, df2.Temp_Obs, color='tab:pink' ,label='Obs_Tempr',linewidth=0.5)
ax[2,0].plot(df2.Date, df2.Temp_Mod,color='tab:blue', linestyle='--',label='Mod_Tempr',linewidth=0.5)

ax[2,0].set_ylabel('Langtang',fontsize=5)
ax[2,0].set_yticks([-10,0,10,20,30])

ax[2,1].plot(df2.Date, df2.RH_Obs, color='tab:pink' ,label='Obs_RH',linewidth=0.5)
ax[2,1].plot(df2.Date, df2.RH_Mod,color='tab:blue', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[2,1].set_yticks([0,25,50,75,100])


ax[2,2].plot(df2.Date, df2.WS_Obs, color='tab:pink' ,label='Obs_Ws',linewidth=0.5)
ax[2,2].plot(df2.Date, df2.WS_Mod,color='tab:blue', linestyle='--',label='Mod_Ws',linewidth=0.5)
ax[2,2].set_yticks([0,5,10,15,20])
ax[2,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)


ax[2,0].tick_params(axis='y', labelsize= 5)
ax[2,1].tick_params(axis='y', labelsize= 5)
ax[2,2].tick_params(axis='y', labelsize= 5)

ax[2,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[2,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[2,2].set(xlim=["2017-01-01", "2017-12-31"])

ax[2,0].set_xticklabels([])
ax[2,1].set_xticklabels([])
ax[2,2].set_xticklabels([])

#============  New Delhi ==============================================
ax[3,0].plot(df3.Date, df3.Temp_Obs, color='lime' ,label='Obs_Tempr',linewidth=0.5)
ax[3,0].plot(df3.Date, df3.Temp_Mod,color='salmon', linestyle='--',label='Mod_Tempr',linewidth=0.5)
ax[3,0].set_yticks([-10,0,10,20,30])

ax[3,1].plot(df3.Date, df3.RH_Obs, color='lime' ,label='Obs_RH',linewidth=0.5)
ax[3,1].plot(df3.Date, df3.RH_Mod,color='salmon', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[3,1].set_yticks([0,25,50,75,100])

ax[3,2].plot(df3.Date, df3.WS_Obs, color='lime' ,label='Obs_Ws',linewidth=0.5)
ax[3,2].plot(df3.Date, df3.WS_Mod, color='salmon', linestyle='--',label='Mod_Ws',linewidth=0.5)

ax[3,2].set_yticks([0,5,10,15,20])
ax[3,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)

ax[3,0].tick_params(axis='y', labelsize= 5)
ax[3,1].tick_params(axis='y', labelsize= 5)
ax[3,2].tick_params(axis='y', labelsize= 5)
ax[3,0].set_ylabel('New-Delhi',fontsize=5)
ax[3,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[3,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[3,2].set(xlim=["2017-01-01", "2017-12-31"])

ax[3,0].set_xticklabels([])
ax[3,1].set_xticklabels([])
ax[3,2].set_xticklabels([])

#===========   Pakistan =============================================================
ax[4,0].plot(df4.Date, df4.Temp_Obs, color='fuchsia' ,label='Obs_Tempr',linewidth=0.5)
ax[4,0].plot(df4.Date, df4.Temp_Mod,color='dodgerblue', linestyle='--',label='Mod_Tempr',linewidth=0.5)
ax[4,0].set_yticks([-10,0,10,20,30])

ax[4,1].plot(df4.Date, df4.RH_Obs, color='fuchsia' ,label='Obs_RH',linewidth=0.5)
ax[4,1].plot(df4.Date, df4.RH_Mod,color='dodgerblue', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[4,1].set_yticks([0,25,50,75,100])

ax[4,0].tick_params(axis='y', labelsize= 5)
ax[4,1].tick_params(axis='y', labelsize= 5)
ax[4,2].tick_params(axis='y', labelsize= 5)

ax[4,2].plot(df4.Date, df4.WS_Obs, color='fuchsia' ,label='Obs_Ws',linewidth=0.5)
ax[4,2].plot(df4.Date, df4.WS_Mod, color='dodgerblue', linestyle='--',label='Mod_Ws',linewidth=0.5)
ax[4,2].set_yticks([0,5,10,15,20])

ax[4,0].set_ylabel('Karachi',fontsize=5)
ax[4,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)

ax[4,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[4,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[4,2].set(xlim=["2017-01-01", "2017-12-31"])

ax[4,0].set_xticklabels([])
ax[4,1].set_xticklabels([])
ax[4,2].set_xticklabels([])

#=============  Plot for  Uzbeksitan =================================================
ax[5,0].plot(df5.Date, df5.Temp_Obs, color='teal' ,label='Obs_Tempr',linewidth=0.5)
ax[5,0].plot(df5.Date, df5.Temp_Mod,color='tan', linestyle='--',label='Mod_Tempr',linewidth=0.5)
ax[5,0].set_yticks([-10,0,10,20,30])

ax[5,1].plot(df5.Date, df5.RH_Obs, color='teal' ,label='Obs_RH',linewidth=0.5)
ax[5,1].plot(df5.Date, df5.RH_Mod,color='tan', linestyle='--',label='Mod_RH',linewidth=0.5)
ax[5,1].set_yticks([0,25,50,75,100])


ax[5,2].plot(df5.Date, df5.WS_Obs, color='teal' ,label='Obs_Ws',linewidth=0.5)
ax[5,2].plot(df4.Date, df4.WS_Mod, color='tan', linestyle='--',label='Mod_Ws',linewidth=0.5)
ax[5,2].set_yticks([0,5,10,15,20])

ax[5,2].legend(loc='upper right', bbox_to_anchor=(1.35, 0.8),fontsize=4)
ax[5,0].set_ylabel('Andizhan',fontsize=5)


ax[5,0].tick_params(axis='y', labelsize= 5)
ax[5,1].tick_params(axis='y', labelsize= 5)
ax[5,2].tick_params(axis='y', labelsize= 5)

ax[5,0].tick_params(axis='x', labelsize= 4)
ax[5,1].tick_params(axis='x', labelsize= 4)
ax[5,2].tick_params(axis='x', labelsize= 4)


#=============================================================
years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y-%m')

# format the ticks
ax[5,0].xaxis.set_major_locator(months)
ax[5,0].xaxis.set_major_formatter(years_fmt)
ax[5,0].xaxis.set_minor_locator(months)

ax[5,1].xaxis.set_major_locator(months)
ax[5,1].xaxis.set_major_formatter(years_fmt)
ax[5,1].xaxis.set_minor_locator(months)

ax[5,2].xaxis.set_major_locator(months)
ax[5,2].xaxis.set_major_formatter(years_fmt)
ax[5,2].xaxis.set_minor_locator(months)

# Set title and labels for axes
ax[5,0].set(xlim=["2017-01-01", "2017-12-31"])
ax[5,1].set(xlim=["2017-01-01", "2017-12-31"])
ax[5,2].set(xlim=["2017-01-01", "2017-12-31"])

#ax[5,0].set_xlabel("Year-Month", fontsize=6)
ax[5,1].set_xlabel("Year-Month", fontsize=5)
#ax[5,2].set_xlabel("Year-Month", fontsize=6)

#ax[5,0].xaxis.set_tick_params(labelsize=7)
#3ax[5,1].xaxis.set_tick_params(labelsize=7)
#ax[5,2].xaxis.set_tick_params(labelsize=7)

fig.subplots_adjust(top=0.935,
                        bottom=0.125,
                        left=0.1154,
                        right=0.89,
                        hspace=0.19,
                        wspace=0.205)



#plt.savefig('/mnt/g/2nd_Paper/Met',dpi=600)
#plt.savefig('Met1.pdf')
plt.show()

#fig,ax = plt.subplots(nrows=4, ncols=2,dpi=200, figsize=(4.5,4.5))
#plt.savefig('wind_wrf_ERA5.png', dpi=200,figsize=(4.5,4.5),top=0.93,bottom=0.06,left=0.11,right=0.9,hspace=0.095,wspace=0.0)
